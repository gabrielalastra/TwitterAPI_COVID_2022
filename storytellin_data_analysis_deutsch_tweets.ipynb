# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import csv
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import word_tokenize 
from nltk.corpus import stopwords
from wordcloud import WordCloud
from PIL import Image
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# <hr color='cian'>
# <h4 align='right'>Open the data</h4>

# %%
path = '/content/drive/MyDrive/Colab Notebooks/archiveDE_clean_jan2022.csv'

# %%
with open(path, 'r') as reader:
  for index, line in enumerate(reader.readlines()):
    if (index<10):
      print(index, line)
# Out:
# 0 ,created_at,text,user,source,favorite_count,retweet_count,location,verified,screen_name
#
# 1 0,2022-01-27 11:00:45+00:00,BTW: Joe Rogan ist übrigens nicht nur wegen COVID-Desinformation ungeil. Bei ihm tauchen auch gerne mal Personen vo… https://t.co/PJYxsEQsWm,"{'id': 83573370, 'id_str': '83573370', 'name': 'Sascha Morlok', 'screen_name': 'modgamers', 'location': 'Hamburg, Germany', 'description': 'Er, he/him | Roboter-Mensch-Kontakter. Schreibe mit an #Shadowrun für @pegasusspiele #pnpde, Unterstützen: https://t.co/YQjSbLnjsA\n\nNazis = Schlecht', 'url': 'https://t.co/UmdNYs80AZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/UmdNYs80AZ', 'expanded_url': 'https://rpggeek.com/rpgdesigner/55518/sascha-morlok', 'display_url': 'rpggeek.com/rpgdesigner/55…', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/YQjSbLnjsA', 'expanded_url': 'http://steadyhq.com/de/saschasr', 'display_url': 'steadyhq.com/de/saschasr', 'indices': [107, 130]}]}}, 'protected': False, 'followers_count': 563, 'friends_count': 604, 'listed_count': 71, 'created_at': 'Mon Oct 19 10:54:35 +0000 2009', 'favourites_count': 27509, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 118898, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/994931882910519296/uMMxPWC7_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/994931882910519296/uMMxPWC7_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/83573370/1421864867', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}",Tw Web AP,0,0,"Hamburg, Germany",No,modgamers
#
# 2 1,2022-01-27 11:00:35+00:00,Welttag der Bildung: Covid-19-Pandemie verschärft Bildungsbenachteiligungen weltweit https://t.co/oHx4lLXtmT,"{'id': 52403524, 'id_str': '52403524', 'name': 'jugendhilfeportal.de', 'screen_name': '_fkp_', 'location': 'Deutschland', 'description': 'Informations-, Kooperations- und Kommunikationsplattform für Fachkräfte der Kinder- und Jugendhilfe. Impressum: https://t.co/4D2wmFc642', 'url': 'http://t.co/1SxISqu939', 'entities': {'url': {'urls': [{'url': 'http://t.co/1SxISqu939', 'expanded_url': 'http://www.jugendhilfeportal.de', 'display_url': 'jugendhilfeportal.de', 'indices': [0, 22]}]}, 'description': {'urls': [{'url': 'https://t.co/4D2wmFc642', 'expanded_url': 'http://bit.ly/2ifwHcV', 'display_url': 'bit.ly/2ifwHcV', 'indices': [112, 135]}]}}, 'protected': False, 'followers_count': 6442, 'friends_count': 2522, 'listed_count': 215, 'created_at': 'Tue Jun 30 14:09:17 +0000 2009', 'favourites_count': 55, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 33663, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'EFEFEF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1396847907/Logo_Fachkraefteportal_RGB_twitter_fb_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1396847907/Logo_Fachkraefteportal_RGB_twitter_fb_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/52403524/1510647611', 'profile_link_color': '19869E', 'profile_sidebar_border_color': '7DB61A', 'profile_sidebar_fill_color': 'EFEFEF', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}",website,0,0,Deutschland,No,_fkp_
#
# 3 2,2022-01-27 11:00:27+00:00,"Experten, darunter
#
# 4 Robert Garry &amp; Mike Farzan erklären
#
# 5 dass die Konfiguration des Virus nicht mit der
#
# 6 anderer Co… https://t.co/EBzOCBZahT","{'id': 1438185116136878083, 'id_str': '1438185116136878083', 'name': 'Geometrie im Kopfsalat', 'screen_name': 'WillyPe37974835', 'location': 'Katzenfurt', 'description': 'Das Profile ist zur Info verlinkt.', 'url': 'https://t.co/v5v1i0eSJv', 'entities': {'url': {'urls': [{'url': 'https://t.co/v5v1i0eSJv', 'expanded_url': 'http://posttraumatische-belastungsstoerung.com/komplexe-ptbs', 'display_url': '…sttraumatische-belastungsstoerung.com/komplexe-ptbs', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 284, 'friends_count': 280, 'listed_count': 0, 'created_at': 'Wed Sep 15 16:57:54 +0000 2021', 'favourites_count': 2632, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 2633, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1485982465122619401/m1lzGxqR_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1485982465122619401/m1lzGxqR_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1438185116136878083/1643205555', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}",Tw Web AP,0,0,Katzenfurt,No,WillyPe37974835
#
# 7 3,2022-01-27 11:00:17+00:00,"@u1829387190039 @SWagenknecht verpflichtend werden darf. Dies lässt aber komplett außen vor, dass die Impfung die W… https://t.co/5O78Cix8wX","{'id': 1338961332125757440, 'id_str': '1338961332125757440', 'name': 'Mario Quade', 'screen_name': 'MarioQuade', 'location': '', 'description': '27, Geschichtsstudent', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 121, 'friends_count': 102, 'listed_count': 0, 'created_at': 'Tue Dec 15 21:38:54 +0000 2020', 'favourites_count': 45366, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 8209, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1411708288375431175/m5rlD2T7_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1411708288375431175/m5rlD2T7_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1338961332125757440/1631088650', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}",Tw Web AP,0,0,,No,MarioQuade
#
# 8 4,2022-01-27 11:00:16+00:00,"@DBOnTweets @Ricarda_Lang Mit falschen Zahlen zu argumentieren, ist nicht hilfreich. Und selbst wenn es tatsächl. n… https://t.co/xjEkcmpRRf","{'id': 92365834, 'id_str': '92365834', 'name': 'Moni W.', 'screen_name': 'fantasmex', 'location': '', 'description': 'Der stärkste naturwissenschaftliche Beweis ist die persönliche Erfahrung!', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 461, 'friends_count': 1473, 'listed_count': 1, 'created_at': 'Tue Nov 24 21:07:44 +0000 2009', 'favourites_count': 9750, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 3492, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1480846446987522049/QyiVy5xe_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1480846446987522049/QyiVy5xe_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/92365834/1641896428', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}",iPhone,0,0,,No,fantasmex
#
# 9 5,2022-01-27 11:00:12+00:00,"@La_Hirt Ganz genau! Doch meine Frage nach der Anzahl Covid-Toten und LongCovid-Kranken aufgrund der Impfung, bezie… https://t.co/uuIXTKmjgJ","{'id': 1078611325134295041, 'id_str': '1078611325134295041', 'name': 'Peter Baumann', 'screen_name': 'PeterBa84734077', 'location': '', 'description': 'Ex Fern- und Busfahrer, pens. Fahrlehrer aller Kat., Dipl. Verkehrsexperte, Humanitäres, Politik, Verkehr, Pazifist, Funkamateur', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1964, 'friends_count': 5002, 'listed_count': 2, 'created_at': 'Fri Dec 28 11:19:14 +0000 2018', 'favourites_count': 96328, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 50893, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1081017735612649472/zbzVQGaP_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1081017735612649472/zbzVQGaP_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}",iPhone,0,0,,No,PeterBa84734077

# %%
df = pd.read_csv(path, sep=',',
                 encoding='UTF-8',
                 skip_blank_lines=False,
                 usecols=['created_at', 'text', 'source',
                          'favorite_count', 'retweet_count',
                          'location', 'verified', 'screen_name'])

# %%
df.head()

# %%
df.isna().value_counts()
# Out:
# Unnamed: 0  created_at  text   user   source  favorite_count  retweet_count  location  verified  screen_name
# False       False       False  False  False   False           False          False     False     False          170
#                                                                              True      False     False          130
# dtype: int64

# %%
df['created_at'] = pd.to_datetime(df['created_at'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   created_at      300 non-null    datetime64[ns, UTC]
#  1   text            300 non-null    object
#  2   source          300 non-null    object
#  3   favorite_count  300 non-null    int64
#  4   retweet_count   300 non-null    int64
#  5   location        170 non-null    object
#  6   verified        300 non-null    object
#  7   screen_name     300 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 18.9+ KB

# %% [markdown]
# <hr color='cian'>
# <h4 align='right'>Visualization</h4>

# %% [markdown]
# <h5 align='right'>WordCloud in 300 tweets about tweet</h5>

# %%
df['tokenized_text'] = df.apply(lambda row: nltk.word_tokenize(row['text']), axis=1)
stopwords = nltk.corpus.stopwords.words('german')

# %%
text = df.tokenized_text
wordcloud = WordCloud(
    width = 3000,
    height = 2000,
    background_color = 'white',
    stopwords=stopwords).generate(str(text))
fig = plt.figure(
    figsize = (10, 10))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# <h5 align='right'>The tweets most RT</h5>

# %%
from IPython.core.pylabtools import figsize
plt.figure(figsize=(9,4))
plt.plot(df['retweet_count'], color='orange')
plt.axhline(df['retweet_count'].mean(), color='blue', lw='.9',linestyle='-.', label='mean')
plt.xlabel('RT index')
plt.ylabel('Number of RT')
plt.legend(loc='upper right')
plt.savefig('DE_RT.jpg')

# %% [markdown]
# <h5 align='right'>Tweets RT above average</h5>

# %%
RTmean = (df['retweet_count'] > df['retweet_count'].mean())
RTmean = df[RTmean]
plt.figure(figsize=(30,6))
plt.plot(RTmean['screen_name'],RTmean['retweet_count'], 'go--')
plt.xlabel('Screen Names')
plt.ylabel('Number of RT')
plt.savefig('DE_RTaboveMean.jpg')

# %%
RTmean['retweet_count'].plot(kind='pie')

# %%
RTmean['tokenized_text'] = RTmean.apply(lambda row: nltk.word_tokenize(row['text']), axis=1)
stopwords = nltk.corpus.stopwords.words('german')

# %% [markdown]
# <h5 align='right'>WordCloud with all the RT above the average</h5>

# %%
text = RTmean.tokenized_text
wordcloud = WordCloud(
    width = 3000,
    height = 2000,
    background_color = 'white',
    stopwords=stopwords).generate(str(text))
fig = plt.figure(
    figsize = (10, 10))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
plt.hist(RTmean['verified'])
plt.xlabel('Verified Accounts')
plt.ylabel('Number of Tweets')
# Out:
# Text(0, 0.5, 'Number of Tweets')

# %% [markdown]
# <h5 align='right'>One tweet had the biggest impact</h5>

# %%
VerY = (RTmean['verified']=='Yes')
VerY = RTmean[VerY]
plt.figure(figsize=(5,5))
plt.plot(VerY['screen_name'], VerY['retweet_count'], label='retweets')
plt.plot(VerY['screen_name'], VerY['favorite_count'], label='favorites')
plt.legend(loc='upper left')
plt.xlabel('screen name')
plt.ylabel('audience')
plt.savefig('RT_byVerifiedAccounts.jpg')

# %%
list(VerY.text)
# Out:
# ['Pfizer, Moderna covid vaccines safe during in vitro fertilization\n\n#arynews \n\nhttps://t.co/ZUyv85Hktu',
#  '„Ab Februar gilt Covid-19 nicht mehr als ‚für die Gesellschaft kritische Krankheit‘. Nachtclubs dürfen dann wieder… https://t.co/uaWY6Gosxi']

# %% [markdown]
# ![Tim_Roehn.png](data:image/png;base64,...)
